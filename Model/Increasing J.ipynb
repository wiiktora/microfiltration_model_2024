# %%
import math
import pandas as pd
from scipy.optimize import minimize_scalar
#data
L= 0.3 # module length in meters
n_f = 6 #number of fibers
i_d = 1.27e-3#internal diameter m
p_s = 0.1e-6 #pore size in meters
T = 298 #K
gamma_w = 32400#shear rate s-1
phi_m = 0.68
eta_0 = 0.000905#Pa.second viscosity of hte TGM
rho_p = 1300 #kg/m3 density of the particles
rho_f = 1000 #kg/m3 density of the fluid
k_B = 1.38064852e-23 #J/mol/K Boltzmann constant
phi_w_guess = [0.64,0.64,0.64] #guess for the volume fraction of solute at the membrane wall
# Particle sizes (in meters)
particles = [
    {'name': '10nm', 'radius': 10e-9, 'phi_b': 0.01},
    {'name': '180nm', 'radius': 180e-9, 'phi_b': 0.05},
    {'name': '300nm', 'radius': 300e-9, 'phi_b': 0.06}
]
phi_w_dict={key:values for key, values in zip([particle['radius'] for particle in particles], phi_w_guess)}
target_species = 10e-9 
#equations
#Step 2 - evaluate the viscosity
    # no particle-particle interactions - dillute suspensions
def viscosity_no_PP(eta_0,phi_b,k1):
    """eta_0 - viscosity of the dispersion medium
    phi - volume in parts occupied by the dispersed solid
    k1 = shape factor"""
    if phi_b<0.1:
        eta_phi = eta_0*(1+5/2*phi_b)
    elif phi_b>0.1:
        eta_phi = eta_0*(1+5/2*phi_b+k1*phi_b**2)
    return eta_phi
# print(eta_f)    


eta_f = viscosity_no_PP(eta_0,sum(particles['phi_b'] for particles in particles),10)
diffusion_coeff = (k_B * T) / (6 * math.pi * eta_f * target_species)


#k1 around 10 for spheres
#not sure about the shape factor

def max_agg_packing (phi_m):
    phi_Max=phi_m+0.74*(1-phi_m)
    return phi_Max
phi_M = max_agg_packing(phi_m)
# phi_M = 0.92

#step 3 - maximum back-transport velocity, u (m/s)- Brownian, shear-infuced and intertial lift - Full retention of all solutes
 #particle volume franction at the membrane wall for each particle size for the first iteration
#J_flux = 30 #LMH


def J_brownian(a, phi_w, phi_b):
    numerator = gamma_w * (k_B ** 2) * (T ** 2)
    denominator = (eta_f ** 2) * (a ** 2) * L
    term = (numerator / denominator) ** (1/3)
    J = 0.114 * term * math.log(phi_w / phi_b)
    return J

# Function to calculate J for shear-induced diffusion
def J_shear(a, phi_w, phi_b):
    term = (a ** 4 / L) ** (1/3)
    log_term = math.log(phi_w / phi_b)
    J = 0.078 * term * gamma_w * abs(log_term)
    return J

# Function to calculate J for inertial lift
def J_inertial(a):
    J = (0.036 * rho_p * (a ** 3) * (gamma_w ** 2)) / eta_f
    return J
#J solvent permeation flux (m/s)


set_data = pd.DataFrame(columns=['name', 'radius', 'max_velocity', 'source'])

def min_flux(Particles, phi_w_list):
    """ have to put particles list with radius and phi_b,
    phi_w_list with phi_w
    results ai_target, J_flux and dataframe"""
    
    min_velocity = float('inf')
    selected_particle_radius = None
    velocities_list=[]

    for particle, phi_w in zip(Particles, phi_w_list):
        a = particle['radius']
        phi_b = particle['phi_b']
        
        # Calculate velocities
        brownian_velocity = J_brownian(a, phi_w, phi_b)
        shear_velocity = J_shear(a, phi_w, phi_b)
        inertial_velocity = J_inertial(a)
        
        # Find the maximum velocity
        max_velocity = max(brownian_velocity, inertial_velocity, shear_velocity)
        
        # Determine the source of the maximum velocity
        source = 'brownian' if max_velocity == brownian_velocity else 'inertial' if max_velocity == inertial_velocity else 'shear'
        
        # Update set_data by replacing previous row or adding a new one
        if particle['name'] in set_data['name'].values:
            set_data.loc[set_data['name'] == particle['name'], ['radius', 'max_velocity', 'source']] = [a, max_velocity, source]
        else:
            set_data.loc[len(set_data)] = [particle['name'], a, max_velocity, source]
        # Store all velocities in the DataFrame
        velocities_list.append({
            'name': particle['name'],
            'radius': a,
            'brownian_velocity': brownian_velocity,
            'shear_velocity': shear_velocity,
            'inertial_velocity': inertial_velocity
        })
        velocities_df=pd.DataFrame(velocities_list)
        # Check for the minimum velocity
        if max_velocity < min_velocity:
            min_velocity = max_velocity
            selected_particle_radius = a

    return selected_particle_radius, min_velocity, set_data,velocities_df

# Initialize variables for particles and inertial-lift properties
# ai_target, min_vel, dataf= min_flux(particles, phi_w_guess)

# Function to calculate φ_w for each particle size
def calculate_phi_w(Particles, a_target, min_velocity, data):
    count = 0
    # Dictionaries to store results
    phi_w_J_dict = {}
    phi_wjI_dict = {}
    inertial_particles = []
    
    for particle in Particles:
        a_particle = particle['radius']
        phi_b_particle = particle['phi_b']
        
        if a_particle != a_target:
            # Retrieve the velocity source from the data DataFrame
            source = data.loc[data['radius'] == a_particle, 'source'].values[0]
            
            # Use the source to choose the max_velocity
            if source == 'inertial':
                max_velocity = J_inertial(a_particle)
            elif source == 'shear':
                max_velocity = J_shear(a_particle, phi_w_dict.get(a_particle, 0.64), phi_b_particle)
            elif source == 'brownian':
                max_velocity = J_brownian(a_particle, phi_w_dict.get(a_particle, 0.64), phi_b_particle)
            else:
                raise ValueError(f"Unknown source {source} for particle {a_particle}")

            if max_velocity >= 10 * min_velocity and source == 'inertial':
                # Handle inertial particles
                phi_wjI = 0
                phi_wjI_dict[a_particle] = phi_wjI
                phi_w_dict[a_particle] = phi_wjI
                phi_w_J_dict[a_particle] = phi_wjI
                inertial_particles.append((a_particle, phi_b_particle, max_velocity))
            elif source == "inertial":
                count += 1
            elif source =="brownian" or source =="shear":
                # Define the objective function based on the source
                def objective_function(phi_w_particle):
                    # Recalculate velocities based on the current wall concentration phi_w_particle
                    if source == 'brownian':
                        max_velocity = J_brownian(a_particle, phi_w_particle, phi_b_particle)
                    elif source == 'shear':
                        max_velocity = J_shear(a_particle, phi_w_particle, phi_b_particle)
                    # elif source == 'inertial':
                    #     max_velocity = J_inertial(a_particle)
                    return abs(max_velocity - min_velocity)

                # Minimize the objective function to find the optimal phi_w for the particle
                result = minimize_scalar(objective_function, bounds=(0, 0.64), method='bounded')

                if result.success:
                    phi_w_optimal = result.x
                    phi_w_dict[a_particle] = phi_w_optimal
                    phi_w_J_dict[a_particle] = phi_w_optimal
                else:
                    print(f"Optimization failed for particle radius {a_particle:.1e} m")
    
    # Handle inertial particles after processing all particles
    if count == 1:
        for a, phi_b, u_j in inertial_particles:
            if phi_w_J_dict[a]!=0:
                phi_wjI = phi_M - sum(phi_w_J_dict.values())
                phi_wjI_dict[a] = phi_wjI
                phi_w_dict[a] = phi_wjI
    elif count > 1:
        total_u_j_inv = sum((phi_b / u_j) for _, phi_b, u_j in inertial_particles)
        phi_w_remaining = phi_M - sum(phi_w_J_dict.values())
        phi_w_jI_sum = sum((phi_b / u_j) / total_u_j_inv * phi_w_remaining for _, phi_b, u_j in inertial_particles)
        if abs(phi_M - (sum(phi_w_J_dict.values()) + phi_w_jI_sum)) > 1e-6:
            print("Warning: φ_M and the sum of φ_w_j do not match closely enough.")
        
        for a, phi_b, u_j in inertial_particles:
            phi_wjI = (phi_b / u_j) / total_u_j_inv * phi_w_remaining
            phi_wjI_dict[a] = phi_wjI
            phi_w_dict[a] = phi_wjI

    return phi_w_dict


# Output the updated dictionary
#print(f"Updated phi_w_dict: {phi_w_dict}")
def packing_constraints(Particles, phi_w_list):
    ai_target, min_vel, dataf,vel= min_flux(Particles, phi_w_list)
    phi_w_updated=calculate_phi_w(Particles, ai_target, min_vel, dataf)
    
    tolerance = 1e-6  # Set a tolerance for convergence
    max_iterations = 1000

    for i in range(max_iterations):
        remaining_phiw_j = {a: phi_w for a, phi_w in phi_w_updated.items() if a != min(phi_w_updated.keys())}
        phi_w_i = phi_w_updated[ai_target] # Wall concentration of the target particle
        # Check if packing constraints are satisfied
        if (phi_M >= sum(phi_w_updated.values())) and (sum(remaining_phiw_j.values()) <= 0.68) and phi_w_updated[min(phi_w_updated.keys())] <= 0.74 * (1 - sum(remaining_phiw_j.values())) and phi_smallest_int<0.74:
            # print(f"Iteration {i}: Packing constraints are met.")
            return phi_w_updated,   min_vel, ai_target, dataf,r_minimum, phi_smallest_int
        
        # Store the previous values of phi_w for comparison
        phi_w_previous = phi_w_updated.copy()
        # Update phi_w for the target particle
        phi_w_i_corrected = phi_M * (phi_w_i / sum(phi_w_updated.values()))
        phi_w_updated[ai_target] = phi_w_i_corrected
        phi_w_updated_list = list(phi_w_updated.values())
        #print(phi_w_updated, J_flux, a_target)
        # Recalculate the flux and phi_w_j values after updating
        ai_target, min_vel, dataf,vel= min_flux(particles, phi_w_updated_list)
        phi_w_updated=calculate_phi_w(particles, ai_target, min_vel, dataf)
        phi_smallest_int= phi_w_updated[min(phi_w_updated.keys())] / (1 -sum(phi_w for phi_w in phi_w_updated.values() if phi_w != phi_w_updated[min(phi_w_updated.keys())]))
#        
#       # #step - 9 - calculate the minimum
        r_minimum = (min(phi_w_updated.keys()) * ( (math.sqrt(2) * ((( 4 * (4 / 3) * math.pi ) / phi_smallest_int )) ** (1/3)) - 2 ))/2
        
        # Check for the change in phi_w values between iterations
        phi_w_diff = sum(abs(phi_w_updated[a] - phi_w_previous[a]) for a in phi_w_updated)

        # If the change in phi_w values is smaller than the tolerance, stop the iteration
        if phi_w_diff < tolerance:
            # print(f"Iteration {i}: Will not converger further.")
            return phi_w_updated,   min_vel, ai_target, dataf,r_minimum, phi_smallest_int
    # If the loop completes without finding a solution
    # print("Warning: No solution found within the iteration limit.")
  
    return phi_w_updated, min_vel, ai_target, dataf,r_minimum, phi_smallest_int

#mass-transfer coefficient calculated from equation  1#step 10


def sieving_parameters(Particles, phi_w_list):
    phi_w_updated, J_flux, ai_target, dataf, r_min, phi_smal_int = packing_constraints(Particles, phi_w_list)
    # print(f"Updated phi_w_dict: {phi_w_updated}. J_flux: {J_flux}", f"ai_target: {ai_target}")
    # print(dataf)
    # print(f"phi_smallest_int: {phi_smal_int:.6f}")
    # print(f"Minimum transmission gap {min(phi_w_updated.keys())}: {r_min} m")
    S_0=0 #iobserved sieving coefficient
    for i in range(50):
        Q=J_flux *n_f*math.pi*i_d*(L+L/20)
        mass_transfer_k = 1.62 * (diffusion_coeff/i_d)*(((4*rho_f*Q)/(math.pi*n_f*i_d*eta_f))**(1/3))*((eta_f/(rho_f*diffusion_coeff))**(1/3))
        print(f"mass transfer coefficient: {mass_transfer_k}")
        lambda_s_min = target_species / r_min
        print(f"lambda_s_min: {lambda_s_min}")
        Sieving_coeff_int = ((1 - lambda_s_min) ** 2) * (2 - ((1 - lambda_s_min) ** 2)) * math.exp(-0.7146 * (lambda_s_min ** 2))
        print(f"Initial Sieving coefficient: {Sieving_coeff_int}")
        delta_m = target_species * ((4 * (4 / 3) * math.pi) / phi_smal_int) ** (1 / 3)
        print(f"delta_m: {delta_m}")
        phi_e_K_d = (1 - lambda_s_min) ** (9 / 2)
        print(f"phi_e_K_d: {phi_e_K_d}")
        cake_membrane_porosity = 1 - phi_smal_int
        print  (f"cake_membrane_porosity: {cake_membrane_porosity}")
        Peclet_m = ((J_flux * delta_m) / diffusion_coeff) * (Sieving_coeff_int / (cake_membrane_porosity * phi_e_K_d))
        print  (f"Peclet_m: {Peclet_m}")
        if Peclet_m >709:
            Peclet_m = 709
        Sieving_coeff_act = (Sieving_coeff_int * math.exp(Peclet_m)) / ((Sieving_coeff_int + math.exp(Peclet_m)) - 1)
        print(f"Actual Sieving coefficient: {Sieving_coeff_act}")
        Sieving_coeff_obs = Sieving_coeff_act / ((1 - Sieving_coeff_act) * math.exp(-J_flux / mass_transfer_k) + Sieving_coeff_act)
        print(f"Sieving coefficient: {Sieving_coeff_obs}")
        yields = 1 - math.exp(-4 * (Sieving_coeff_obs))
        print(f"Yields: {yields}")
        if (abs(S_0-Sieving_coeff_obs)/Sieving_coeff_obs) < 0.1:
            print(f"Convergence reached after {i} iterations.")
            print(f"Final Sieving coefficient (obs): {Sieving_coeff_obs}")
            print(f"Final Yield: {yields}")
            print(f"Final flux: {J_flux}")
            for particle in Particles:
                name = particle['name']
                phi_b = particle['phi_b']
                phi_w = phi_w_updated[particle['radius']]
                print(f"Particle {name}:")
                print(f"  Bulk concentration (phi_b): {phi_b}")
                print(f"  Wall concentration (phi_w): {phi_w}")
            return 
        if yields>0.95:
            print(f"Final iteration {i}")
            print(f"Final Sieving coefficient (obs): {Sieving_coeff_obs}")
            print(f"Final Yield: {yields}")
            print(f"Final flux: {J_flux}")
            for particle in Particles:
                name = particle['name']
                phi_b = particle['phi_b']
                phi_w = phi_w_updated[particle['radius']]
                print(f"Particle {name}:")
                print(f"  Bulk concentration (phi_b): {phi_b}")
                print(f"  Wall concentration (phi_w): {phi_w}")
            return 
        S_0=Sieving_coeff_obs
    # print(f"Yields: {yields}")
        if Sieving_coeff_obs <0.75:
            J_flux = J_flux + J_flux*0.05
            print(f"J_flux increased to {J_flux}")
        for j in range(50):
                    phi_w_updated=calculate_phi_w(Particles, ai_target, J_flux, dataf)
                   
                    phi_w_i = phi_w_updated[ai_target] # Wall concentration of the target particle
                    # Store the previous values of phi_w for comparison
                    phi_w_previous = phi_w_updated.copy()
                    # Update phi_w for the target particle
                    phi_w_i_corrected = phi_M * (phi_w_i / sum(phi_w_updated.values()))
                    phi_w_updated[ai_target] = phi_w_i_corrected
                    ai_target, J_flux, dataf,vel= min_flux(Particles, phi_w_updated.values())
                    
                    
                
                    # Recalculate the flux and
                    
                    # print(dataf)
                    phi_smal_int= phi_w_updated[min(phi_w_updated.keys())] / (1 -sum(phi_w for phi_w in phi_w_updated.values() if phi_w != phi_w_dict[min(phi_w_dict.keys())]))
                #       # #step - 9 - calculate the minimum
                    r_min = (min(phi_w_updated.keys()) * ( (math.sqrt(2) * ((( 4 * (4 / 3) * math.pi ) / phi_smal_int )) ** (1/3)) - 2 ))/2
                    remaining_phiw_j = {a: phi_w for a, phi_w in phi_w_updated.items() if a != min(phi_w_updated.keys())}
                
                    if (phi_M >= sum(phi_w_updated.values())) and (sum(remaining_phiw_j.values()) <= 0.68) and phi_w_updated[min(phi_w_updated.keys())] <= 0.74 * (1 - sum(remaining_phiw_j.values())) and phi_smal_int<0.74:
                        print(f"Iteration {j}: Packing constraints are met.")
                        print(phi_w_updated)
                        break
                    # Check for the change in phi_w values between iterations

                    phi_w_diff = sum(abs(phi_w_updated[a] - phi_w_previous[a]) for a in phi_w_updated)
                    
                    # If the change in phi_w values is smaller than the tolerance, stop the iteration
                    if phi_w_diff < 10e-6:
                        print(f"Iteration {j}: Will not converger further.")
                        break

    print("Warning: No solution found within the iteration limit.")
    return dataf, phi_w_updated,yields
print(sieving_parameters(particles, phi_w_guess))
# Out:
# mass transfer coefficient: 1.8227468716742183e-06
# lambda_s_min: 0.9687120610424401
# Initial Sieving coefficient: 0.0010007851705221024
# delta_m: 2.874104090474135e-08
# phi_e_K_d: 1.6951038114225828e-07
# cake_membrane_porosity: 0.2942658676737824
# Peclet_m: 286.57237386708044
# Actual Sieving coefficient: 0.0010007851705221024
# Sieving coefficient: 0.08690128689642021
# Yields: 0.2936222638889656
# J_flux increased to 8.715633456267763e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2596345446807253), 1.8e-07: np.float64(0.4507462078774318), 3e-07: np.float64(0.17654501080430016)}
# mass transfer coefficient: 1.8140459161178604e-06
# lambda_s_min: 0.9604966401768248
# Initial Sieving coefficient: 0.0016130484744318577
# delta_m: 2.8865909796566604e-08
# phi_e_K_d: 4.840086863193225e-07
# cake_membrane_porosity: 0.30338495443439795
# Peclet_m: 155.33823762291075
# Actual Sieving coefficient: 0.0016130484744318577
# Sieving coefficient: 0.12814175200739056
# Yields: 0.4010439213602278
# J_flux increased to 8.591415028155836e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.23216872390851181), 1.8e-07: np.float64(0.3920685678516089), 3e-07: np.float64(0.19634624407390566)}
# mass transfer coefficient: 1.793047324504966e-06
# lambda_s_min: 0.8404224518371257
# Initial Sieving coefficient: 0.03035340182816311
# delta_m: 3.0969548543051325e-08
# phi_e_K_d: 0.0002590437069238112
# cake_membrane_porosity: 0.4359157456694098
# Peclet_m: 3.938129317560769
# Actual Sieving coefficient: 0.030937918273326145
# Sieving coefficient: 0.7235940463676539
# Yields: 0.9446664678080985
# J_flux increased to 8.296504045180141e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.25160286285104816), 1.8e-07: np.float64(0.4345905385475264), 3e-07: np.float64(0.17922588917291898)}
# mass transfer coefficient: 1.8081965736847684e-06
# lambda_s_min: 0.9198080263259953
# Initial Sieving coefficient: 0.007003662032328848
# delta_m: 2.9517230446744313e-08
# phi_e_K_d: 1.1710867325941224e-05
# cake_membrane_porosity: 0.34848895470645436
# Peclet_m: 24.57580244755833
# Actual Sieving coefficient: 0.007003662032476466
# Sieving coefficient: 0.3839514316460306
# Yields: 0.7847178372906992
# J_flux increased to 8.50857435838503e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.25767276508147063), 1.8e-07: np.float64(0.4592902820888637), 3e-07: np.float64(0.1843101358139085)}
# mass transfer coefficient: 1.81264054435572e-06
# lambda_s_min: 0.9842509311351397
# Initial Sieving coefficient: 0.00024822037703810284
# delta_m: 2.8510560561282983e-08
# phi_e_K_d: 7.72052740778258e-09
# cake_membrane_porosity: 0.2770115959025561
# Peclet_m: 1617.2658341474662
# Actual Sieving coefficient: 0.00024822037703810284
# Sieving coefficient: 0.021936856267483602
# Yields: 0.08400779582475149
# J_flux increased to 8.571462754037456e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.27736747793624195), 1.8e-07: np.float64(0.4216942584041128), 3e-07: np.float64(0.1765135367545268)}
# mass transfer coefficient: 1.813943991275524e-06
# lambda_s_min: 0.9548289148079462
# Initial Sieving coefficient: 0.0021250300452095245
# delta_m: 2.8953307975560585e-08
# phi_e_K_d: 8.848555085597901e-07
# cake_membrane_porosity: 0.3096743177340763
# Peclet_m: 109.97789672748861
# Actual Sieving coefficient: 0.0021250300452095245
# Sieving coefficient: 0.16221708063620832
# Yields: 0.4773631013863088
# J_flux increased to 8.589966945589614e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.26098088567150546), 1.8e-07: np.float64(0.45065632308710457), 3e-07: np.float64(0.17684872174853794)}
# mass transfer coefficient: 1.8150084450100028e-06
# lambda_s_min: 0.9641134243421672
# Initial Sieving coefficient: 0.0013247756798490968
# delta_m: 2.8810674891691457e-08
# phi_e_K_d: 3.141912508303695e-07
# cake_membrane_porosity: 0.2993706839429495
# Peclet_m: 199.10237723227388
# Actual Sieving coefficient: 0.0013247756798490968
# Sieving coefficient: 0.10814088174477779
# Yields: 0.35115636725074006
# J_flux increased to 8.605098045210783e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2306954785265323), 1.8e-07: np.float64(0.39043756776700894), 3e-07: np.float64(0.19679065061817505)}
# mass transfer coefficient: 1.7918366908669198e-06
# lambda_s_min: 0.8356757365189542
# Initial Sieving coefficient: 0.03234431788111863
# delta_m: 3.106512980164099e-08
# phi_e_K_d: 0.00029556814422682624
# cake_membrane_porosity: 0.441106468993539
# Peclet_m: 3.638425331030556
# Actual Sieving coefficient: 0.0331887479230417
# Sieving coefficient: 0.7367151854157902
# Yields: 0.9474957280208284
# J_flux increased to 8.279710433461922e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.2511246605398288), 1.8e-07: np.float64(0.4326936870721771), 3e-07: np.float64(0.17882845754698828)}
# mass transfer coefficient: 1.8078409806185237e-06
# lambda_s_min: 0.9152186368039307
# Initial Sieving coefficient: 0.007872502910286431
# delta_m: 2.9594329290937327e-08
# phi_e_K_d: 1.504360005296911e-05
# cake_membrane_porosity: 0.35356763053161677
# Peclet_m: 21.238596240557598
# Actual Sieving coefficient: 0.007872502914951684
# Sieving coefficient: 0.41174556857946687
# Yields: 0.8073696620900448
# J_flux increased to 8.503555553802397e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.2575292056317077), 1.8e-07: np.float64(0.45868781430146727), 3e-07: np.float64(0.1841874434132896)}
# mass transfer coefficient: 1.8125369023635112e-06
# lambda_s_min: 0.9825670569144161
# Initial Sieving coefficient: 0.00030484900828520786
# delta_m: 2.853518444845128e-08
# phi_e_K_d: 1.2194618136348659e-08
# cake_membrane_porosity: 0.278881647953662
# Peclet_m: 1249.9308141299348
# Actual Sieving coefficient: 0.00030484900828520786
# Sieving coefficient: 0.026795382267264134
# Yields: 0.10163742073506188
# J_flux increased to 8.569992557391846e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.27735496775198737), 1.8e-07: np.float64(0.4216462246666919), 3e-07: np.float64(0.17650230698056782)}
# mass transfer coefficient: 1.8139103632263045e-06
# lambda_s_min: 0.9547091003435675
# Initial Sieving coefficient: 0.0021366558189144813
# delta_m: 2.8955166753990077e-08
# phi_e_K_d: 8.954663367924296e-07
# cake_membrane_porosity: 0.30980725567853706
# Peclet_m: 109.22330931816468
# Actual Sieving coefficient: 0.0021366558189144813
# Sieving coefficient: 0.16293870920705322
# Yields: 0.4788695250565024
# J_flux increased to 8.589489215608667e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.23237866542026464), 1.8e-07: np.float64(0.39229903545306094), 3e-07: np.float64(0.19628388288869417)}
# mass transfer coefficient: 1.793218283025626e-06
# lambda_s_min: 0.8410994792694276
# Initial Sieving coefficient: 0.030075201660732742
# delta_m: 3.0956003628993174e-08
# phi_e_K_d: 0.0002541346844934983
# cake_membrane_porosity: 0.4351749701698179
# Peclet_m: 3.983576251085555
# Actual Sieving coefficient: 0.03062831740176335
# Sieving coefficient: 0.7216826004225452
# Yields: 0.9442417781112276
# J_flux increased to 8.298877367864057e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.27195943932154737), 1.8e-07: np.float64(0.4263694328921093), 3e-07: np.float64(0.1792817228979965)}
# mass transfer coefficient: 1.8170651772697397e-06
# lambda_s_min: 0.9542125201825601
# Initial Sieving coefficient: 0.0021851965785505273
# delta_m: 2.8962875579045387e-08
# phi_e_K_d: 9.405033159393741e-07
# cake_membrane_porosity: 0.3103582188342979
# Peclet_m: 106.7500773908398
# Actual Sieving coefficient: 0.0021851965785505273
# Sieving coefficient: 0.1682179990728322
# Yields: 0.48975893899101286
# J_flux increased to 8.634384596193502e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.260512486963072), 1.8e-07: np.float64(0.4506867829788731), 3e-07: np.float64(0.17674445739130926)}
# mass transfer coefficient: 1.8146764799901304e-06
# lambda_s_min: 0.9628557073005981
# Initial Sieving coefficient: 0.001421656536224616
# delta_m: 2.882983546961851e-08
# phi_e_K_d: 3.668718740920153e-07
# cake_membrane_porosity: 0.30076669009523005
# Peclet_m: 182.15386882198771
# Actual Sieving coefficient: 0.001421656536224616
# Sieving coefficient: 0.11498038500562002
# Yields: 0.3686668220493071
# J_flux increased to 8.600377291795995e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776423976028367), 1.8e-07: np.float64(0.42257971113867593), 3e-07: np.float64(0.1767010198680988)}
# mass transfer coefficient: 1.8145386020095166e-06
# lambda_s_min: 0.9571130179701881
# Initial Sieving coefficient: 0.0019097802994890844
# delta_m: 2.8917961840913848e-08
# phi_e_K_d: 7.00591213755377e-07
# cake_membrane_porosity: 0.30713988798095304
# Peclet_m: 125.83367771271274
# Actual Sieving coefficient: 0.0019097802994890842
# Sieving coefficient: 0.14856763675686757
# Yields: 0.4480349483996018
# J_flux increased to 8.598417086923682e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.26089054686226926), 1.8e-07: np.float64(0.45066304286420533), 3e-07: np.float64(0.1768288665211087)}
# mass transfer coefficient: 1.8149455122446012e-06
# lambda_s_min: 0.9638726793309591
# Initial Sieving coefficient: 0.0013430435552131133
# delta_m: 2.881433863040529e-08
# phi_e_K_d: 3.23788106987955e-07
# cake_membrane_porosity: 0.2996379046915021
# Peclet_m: 195.69510204030252
# Actual Sieving coefficient: 0.0013430435552131133
# Sieving coefficient: 0.10944010297371635
# Yields: 0.3545195862380731
# J_flux increased to 8.60420296864894e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776782730079981), 1.8e-07: np.float64(0.4226990337698257), 3e-07: np.float64(0.17672458274213643)}
# mass transfer coefficient: 1.8146153435881363e-06
# lambda_s_min: 0.9574164459699632
# Initial Sieving coefficient: 0.0018820952406964988
# delta_m: 2.8913279030823236e-08
# phi_e_K_d: 6.785604951910626e-07
# cake_membrane_porosity: 0.3068031854746369
# Peclet_m: 128.17175089075315
# Actual Sieving coefficient: 0.0018820952406964988
# Sieving coefficient: 0.1467742712280702
# Yields: 0.44406121233067763
# J_flux increased to 8.599508081638672e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.23129580385201245), 1.8e-07: np.float64(0.391103714275517), 3e-07: np.float64(0.19660913732912533)}
# mass transfer coefficient: 1.79233113412901e-06
# lambda_s_min: 0.8376086120783024
# Initial Sieving coefficient: 0.031525053976518384
# delta_m: 3.102607809972939e-08
# phi_e_K_d: 0.0002802421597976152
# cake_membrane_porosity: 0.43899341817413573
# Peclet_m: 3.756592264740976
# Actual Sieving coefficient: 0.03225487515887534
# Sieving coefficient: 0.7314293947157439
# Yields: 0.9463738029226826
# J_flux increased to 8.28656648818878e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.25132051709873493), 1.8e-07: np.float64(0.4334662888771251), 3e-07: np.float64(0.17898912750338059)}
# mass transfer coefficient: 1.8079867190245427e-06
# lambda_s_min: 0.9170823052368576
# Initial Sieving coefficient: 0.007513024606014526
# delta_m: 2.9562927784886452e-08
# phi_e_K_d: 1.3611703736933305e-05
# cake_membrane_porosity: 0.3515055358237421
# Peclet_m: 22.513933443377052
# Actual Sieving coefficient: 0.007513024607258646
# Sieving coefficient: 0.4005601138820988
# Yields: 0.7985553158294513
# J_flux increased to 8.505612252184288e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.25758793482460624), 1.8e-07: np.float64(0.45893505091233167), 3e-07: np.float64(0.18423760859291013)}
# mass transfer coefficient: 1.8125793100105645e-06
# lambda_s_min: 0.983256451762633
# Initial Sieving coefficient: 0.0002809460195268854
# delta_m: 2.85250929878846e-08
# phi_e_K_d: 1.0169831081958025e-08
# cake_membrane_porosity: 0.2781160365474007
# Peclet_m: 1384.679649784905
# Actual Sieving coefficient: 0.0002809460195268854
# Sieving coefficient: 0.024750876897384335
# Yields: 0.09426046894452589
# J_flux increased to 8.570594103858138e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2773602457921805), 1.8e-07: np.float64(0.4216646997610413), 3e-07: np.float64(0.1765067823552327)}
# mass transfer coefficient: 1.8139241134101124e-06
# lambda_s_min: 0.9547564676832683
# Initial Sieving coefficient: 0.0021320556979877044
# delta_m: 2.8954431850481907e-08
# phi_e_K_d: 8.912597008302768e-07
# cake_membrane_porosity: 0.30975470020662377
# Peclet_m: 109.52085722486676
# Actual Sieving coefficient: 0.0021320556979877044
# Sieving coefficient: 0.1626536497070132
# Yields: 0.4782749733851428
# J_flux increased to 8.589684552632855e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2609840076571871), 1.8e-07: np.float64(0.4506558764847076), 3e-07: np.float64(0.17685015088097542)}
# mass transfer coefficient: 1.8150119477575757e-06
# lambda_s_min: 0.9641226401525632
# Initial Sieving coefficient: 0.0013240789762999103
# delta_m: 2.881053467874442e-08
# phi_e_K_d: 3.1382832913100553e-07
# cake_membrane_porosity: 0.2993604545827132
# Peclet_m: 199.23478795948216
# Actual Sieving coefficient: 0.0013240789762999103
# Sieving coefficient: 0.10809177032285829
# Yields: 0.35102889219655675
# J_flux increased to 8.605147865713619e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776869835717524), 1.8e-07: np.float64(0.42272639490443725), 3e-07: np.float64(0.17673323798388246)}
# mass transfer coefficient: 1.8146369471239574e-06
# lambda_s_min: 0.9574922151653994
# Initial Sieving coefficient: 0.001875215165428578
# delta_m: 2.891211014648778e-08
# phi_e_K_d: 6.731442357804931e-07
# cake_membrane_porosity: 0.30671910655555323
# Peclet_m: 128.76542198813172
# Actual Sieving coefficient: 0.001875215165428578
# Sieving coefficient: 0.14632879919389288
# Yields: 0.4430697084880715
# J_flux increased to 8.59981522440584e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2608774692083549), 1.8e-07: np.float64(0.450662719397528), 3e-07: np.float64(0.17682612083750973)}
# mass transfer coefficient: 1.8149362138612285e-06
# lambda_s_min: 0.9638358520769791
# Initial Sieving coefficient: 0.0013458495603587968
# delta_m: 2.881489924136971e-08
# phi_e_K_d: 3.2527603423410146e-07
# cake_membrane_porosity: 0.2996787817767478
# Peclet_m: 195.18108756238453
# Actual Sieving coefficient: 0.0013458495603587968
# Sieving coefficient: 0.10963944277626518
# Yields: 0.35503406085319267
# J_flux increased to 8.60407072539305e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776768995424396), 1.8e-07: np.float64(0.42269478163511165), 3e-07: np.float64(0.17672377570263606)}
# mass transfer coefficient: 1.8146127865375953e-06
# lambda_s_min: 0.9574054666069511
# Initial Sieving coefficient: 0.0018830932999964298
# delta_m: 2.891344842378288e-08
# phi_e_K_d: 6.793481433801402e-07
# cake_membrane_porosity: 0.30681536893719474
# Peclet_m: 128.0861584208107
# Actual Sieving coefficient: 0.0018830932999964298
# Sieving coefficient: 0.14683920706290365
# Yields: 0.444205594975825
# J_flux increased to 8.599471727908028e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.23130254989901897), 1.8e-07: np.float64(0.39110790603186285), 3e-07: np.float64(0.19660727334861236)}
# mass transfer coefficient: 1.7923354875953516e-06
# lambda_s_min: 0.837626473151616
# Initial Sieving coefficient: 0.03151753833662851
# delta_m: 3.102571807608633e-08
# phi_e_K_d: 0.00028010348199490885
# cake_membrane_porosity: 0.4389738881207186
# Peclet_m: 3.7577070633185956
# Actual Sieving coefficient: 0.032246359559334886
# Sieving coefficient: 0.7313799961581118
# Yields: 0.9463632056485893
# J_flux increased to 8.28662687107546e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.27063552742198693), 1.8e-07: np.float64(0.42649368036972646), 3e-07: np.float64(0.17899054398555875)}
# mass transfer coefficient: 1.8171475129853974e-06
# lambda_s_min: 0.950924647706546
# Initial Sieving coefficient: 0.002521157890451617
# delta_m: 2.901411907461653e-08
# phi_e_K_d: 1.2849475972887334e-06
# cake_membrane_porosity: 0.3140058164221283
# Peclet_m: 89.26987978407139
# Actual Sieving coefficient: 0.002521157890451617
# Sieving coefficient: 0.18930226403630984
# Yields: 0.5310265191410224
# J_flux increased to 8.635558385319785e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.26049972933525634), 1.8e-07: np.float64(0.45068705046064156), 3e-07: np.float64(0.1767423483948052)}
# mass transfer coefficient: 1.8146673932983923e-06
# lambda_s_min: 0.9628217425669062
# Initial Sieving coefficient: 0.0014243224200428477
# delta_m: 2.88303535964864e-08
# phi_e_K_d: 3.6838389565308756e-07
# cake_membrane_porosity: 0.30080438838977164
# Peclet_m: 181.72415407134488
# Actual Sieving coefficient: 0.0014243224200428477
# Sieving coefficient: 0.11516682922975352
# Yields: 0.3691374802226278
# J_flux increased to 8.600248097550917e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776409176218215), 1.8e-07: np.float64(0.4225765307239879), 3e-07: np.float64(0.17670009244975735)}
# mass transfer coefficient: 1.8145364691829758e-06
# lambda_s_min: 0.9571032889799572
# Initial Sieving coefficient: 0.0019106715016081327
# delta_m: 2.891811203773228e-08
# phi_e_K_d: 7.013066845174621e-07
# cake_membrane_porosity: 0.3071506837940209
# Peclet_m: 125.75975253483878
# Actual Sieving coefficient: 0.001910671501608133
# Sieving coefficient: 0.14862543243946852
# Yields: 0.4481625384384432
# J_flux increased to 8.59838676696698e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.26089101144133814), 1.8e-07: np.float64(0.4506629852393718), 3e-07: np.float64(0.17682896257818698)}
# mass transfer coefficient: 1.814945842556084e-06
# lambda_s_min: 0.9638738680330636
# Initial Sieving coefficient: 0.0013429530345790213
# delta_m: 2.8814320535840042e-08
# phi_e_K_d: 3.2374016835147493e-07
# cake_membrane_porosity: 0.2996365852688656
# Peclet_m: 195.71173410262026
# Actual Sieving coefficient: 0.0013429530345790213
# Sieving coefficient: 0.10943368528787488
# Yields: 0.35450301606334034
# J_flux increased to 8.6042076664223e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776783219223486), 1.8e-07: np.float64(0.4226991851217537), 3e-07: np.float64(0.1767246113667931)}
# mass transfer coefficient: 1.814615434283095e-06
# lambda_s_min: 0.9574168366802306
# Initial Sieving coefficient: 0.0018820597290091297
# delta_m: 2.891327300289771e-08
# phi_e_K_d: 6.785324791328103e-07
# cake_membrane_porosity: 0.3068027519153187
# Peclet_m: 128.17479815977288
# Actual Sieving coefficient: 0.0018820597290091297
# Sieving coefficient: 0.1467719603739999
# Yields: 0.44405607353328624
# J_flux increased to 8.599509371055853e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2312956841828059), 1.8e-07: np.float64(0.391103565689816), 3e-07: np.float64(0.19660917374284292)}
# mass transfer coefficient: 1.7923310357214826e-06
# lambda_s_min: 0.8376082070344205
# Initial Sieving coefficient: 0.031525224423832945
# delta_m: 3.1026086264331345e-08
# phi_e_K_d: 0.0002802453052778734
# cake_membrane_porosity: 0.4389938610654036
# Peclet_m: 3.7565669911611264
# Actual Sieving coefficient: 0.032255068293270864
# Sieving coefficient: 0.7314305151712316
# Yields: 0.9463740432652112
# J_flux increased to 8.286565123272793e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.251320477913127), 1.8e-07: np.float64(0.43346613557634095), 3e-07: np.float64(0.17898909548499675)}
# mass transfer coefficient: 1.8079866898799336e-06
# lambda_s_min: 0.9170819336245702
# Initial Sieving coefficient: 0.007513095375520132
# delta_m: 2.956293403357115e-08
# phi_e_K_d: 1.3611978255203662e-05
# cake_membrane_porosity: 0.35150594703833005
# Peclet_m: 22.51366879515313
# Actual Sieving coefficient: 0.007513095376764594
# Sieving coefficient: 0.4005623580613771
# Yields: 0.7985571241332787
# J_flux increased to 8.505611840854816e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.25758792345619286), 1.8e-07: np.float64(0.4589350001483943), 3e-07: np.float64(0.18423759855175412)}
# mass transfer coefficient: 1.812579301802697e-06
# lambda_s_min: 0.9832563123088099
# Initial Sieving coefficient: 0.0002809507538399984
# delta_m: 2.8525095027798675e-08
# phi_e_K_d: 1.0170212249147852e-08
# cake_membrane_porosity: 0.2781161914195741
# Peclet_m: 1384.6503956410193
# Actual Sieving coefficient: 0.0002809507538399984
# Sieving coefficient: 0.024751282788946432
# Yields: 0.09426193947146466
# J_flux increased to 8.570593987427975e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.277360243778291), 1.8e-07: np.float64(0.42166469566928605), 3e-07: np.float64(0.17650678398842487)}
# mass transfer coefficient: 1.8139241106583247e-06
# lambda_s_min: 0.9547564593598985
# Initial Sieving coefficient: 0.0021320565058597766
# delta_m: 2.895443197961245e-08
# phi_e_K_d: 8.912604386658806e-07
# cake_membrane_porosity: 0.3097547094416605
# Peclet_m: 109.52080478134874
# Actual Sieving coefficient: 0.0021320565058597766
# Sieving coefficient: 0.16265369956114892
# Yields: 0.4782750774257335
# J_flux increased to 8.589684513540282e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2609840080455925), 1.8e-07: np.float64(0.45065587643063215), 3e-07: np.float64(0.17685015106395388)}
# mass transfer coefficient: 1.8150119480336098e-06
# lambda_s_min: 0.9641226413103996
# Initial Sieving coefficient: 0.0013240788887809824
# delta_m: 2.881053466112881e-08
# phi_e_K_d: 3.1382828355551525e-07
# cake_membrane_porosity: 0.29936045329753813
# Peclet_m: 199.23480454860885
# Actual Sieving coefficient: 0.0013240788887809824
# Sieving coefficient: 0.10809176407444915
# Yields: 0.3510288759764085
# J_flux increased to 8.60514786963973e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.27768698360771243), 1.8e-07: np.float64(0.4227263950331638), 3e-07: np.float64(0.17673323800548874)}
# mass transfer coefficient: 1.8146369472102432e-06
# lambda_s_min: 0.9574922154807934
# Initial Sieving coefficient: 0.0018752151368174154
# delta_m: 2.8912110141622608e-08
# phi_e_K_d: 6.73144213305185e-07
# cake_membrane_porosity: 0.30671910620556875
# Peclet_m: 128.76542446640852
# Actual Sieving coefficient: 0.0018752151368174154
# Sieving coefficient: 0.14632879733800952
# Yields: 0.44306970435368076
# J_flux increased to 8.599815225632602e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.260877469185298), 1.8e-07: np.float64(0.45066271940099106), 3e-07: np.float64(0.17682612083407342)}
# mass transfer coefficient: 1.8149362138448342e-06
# lambda_s_min: 0.9638358520212609
# Initial Sieving coefficient: 0.0013458495646064893
# delta_m: 2.8814899242217923e-08
# phi_e_K_d: 3.252760364892932e-07
# cake_membrane_porosity: 0.2996787818385933
# Peclet_m: 195.18108678535768
# Actual Sieving coefficient: 0.0013458495646064893
# Sieving coefficient: 0.10963944307681626
# Yields: 0.35503406162857354
# J_flux increased to 8.60407072515989e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.27767689954000907), 1.8e-07: np.float64(0.42269478162767465), 3e-07: np.float64(0.17672377570121092)}
# mass transfer coefficient: 1.8146127865330797e-06
# lambda_s_min: 0.9574054665876637
# Initial Sieving coefficient: 0.0018830933017499661
# delta_m: 2.891344842408046e-08
# phi_e_K_d: 6.79348144764427e-07
# cake_membrane_porosity: 0.30681536895859773
# Peclet_m: 128.0861582705143
# Actual Sieving coefficient: 0.0018830933017499661
# Sieving coefficient: 0.146839207176968
# Yields: 0.4442055952294103
# J_flux increased to 8.59947172784383e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.23130254990509871), 1.8e-07: np.float64(0.3911079060392697), 3e-07: np.float64(0.19660727334676725)}
# mass transfer coefficient: 1.7923354876008524e-06
# lambda_s_min: 0.8376264731720235
# Initial Sieving coefficient: 0.03151753832804192
# delta_m: 3.102571807567499e-08
# phi_e_K_d: 0.00028010348183648995
# cake_membrane_porosity: 0.438973888098404
# Peclet_m: 3.757707064595902
# Actual Sieving coefficient: 0.03224635954960389
# Sieving coefficient: 0.7313799961021591
# Yields: 0.9463632056365848
# J_flux increased to 8.286626871151752e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.2706355274301857), 1.8e-07: np.float64(0.426493680368979), 3e-07: np.float64(0.17899054398734845)}
# mass transfer coefficient: 1.817147512984902e-06
# lambda_s_min: 0.9509246477269138
# Initial Sieving coefficient: 0.0025211578882916312
# delta_m: 2.901411907429799e-08
# phi_e_K_d: 1.2849475948889114e-06
# cake_membrane_porosity: 0.3140058163995342
# Peclet_m: 89.2698798796845
# Actual Sieving coefficient: 0.0025211578882916312
# Sieving coefficient: 0.18930226390411722
# Yields: 0.5310265188930432
# J_flux increased to 8.635558385312724e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.26049972933532367), 1.8e-07: np.float64(0.45068705046063284), 3e-07: np.float64(0.17674234839482975)}
# mass transfer coefficient: 1.8146673932984404e-06
# lambda_s_min: 0.962821742567096
# Initial Sieving coefficient: 0.0014243224200279478
# delta_m: 2.8830353596483504e-08
# phi_e_K_d: 3.6838389564462745e-07
# cake_membrane_porosity: 0.30080438838956125
# Peclet_m: 181.7241540737405
# Actual Sieving coefficient: 0.0014243224200279478
# Sieving coefficient: 0.11516682922871026
# Yields: 0.36913748021999515
# J_flux increased to 8.600248097551598e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776409176218232), 1.8e-07: np.float64(0.42257653072400964), 3e-07: np.float64(0.1767000924497768)}
# mass transfer coefficient: 1.8145364691829907e-06
# lambda_s_min: 0.9571032889800255
# Initial Sieving coefficient: 0.0019106715016018775
# delta_m: 2.891811203773123e-08
# phi_e_K_d: 7.013066845124389e-07
# cake_membrane_porosity: 0.3071506837939454
# Peclet_m: 125.75975253535721
# Actual Sieving coefficient: 0.0019106715016018773
# Sieving coefficient: 0.14862543243906257
# Yields: 0.44816253843754705
# J_flux increased to 8.598386766967189e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.26089101144133475), 1.8e-07: np.float64(0.4506629852393723), 3e-07: np.float64(0.17682896257818628)}
# mass transfer coefficient: 1.8149458425560814e-06
# lambda_s_min: 0.9638738680330555
# Initial Sieving coefficient: 0.0013429530345796387
# delta_m: 2.881432053584017e-08
# phi_e_K_d: 3.2374016835180173e-07
# cake_membrane_porosity: 0.29963658526887504
# Peclet_m: 195.71173410250654
# Actual Sieving coefficient: 0.0013429530345796387
# Sieving coefficient: 0.10943368528791864
# Yields: 0.35450301606345325
# J_flux increased to 8.604207666422266e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2776783219223482), 1.8e-07: np.float64(0.4226991851217527), 3e-07: np.float64(0.17672461136679288)}
# mass transfer coefficient: 1.8146154342830941e-06
# lambda_s_min: 0.9574168366802277
# Initial Sieving coefficient: 0.0018820597290093919
# delta_m: 2.8913273002897753e-08
# phi_e_K_d: 6.785324791330173e-07
# cake_membrane_porosity: 0.3068027519153218
# Peclet_m: 128.17479815975037
# Actual Sieving coefficient: 0.0018820597290093919
# Sieving coefficient: 0.14677196037401705
# Yields: 0.44405607353332444
# J_flux increased to 8.599509371055845e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.23129568418280663), 1.8e-07: np.float64(0.3911035656898169), 3e-07: np.float64(0.1966091737428427)}
# mass transfer coefficient: 1.7923310357214832e-06
# lambda_s_min: 0.837608207034423
# Initial Sieving coefficient: 0.03152522442383192
# delta_m: 3.102608626433129e-08
# phi_e_K_d: 0.0002802453052778544
# cake_membrane_porosity: 0.43899386106540095
# Peclet_m: 3.756566991161279
# Actual Sieving coefficient: 0.0322550682932697
# Sieving coefficient: 0.731430515171225
# Yields: 0.9463740432652098
# J_flux increased to 8.286565123272802e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.25132047791312717), 1.8e-07: np.float64(0.4334661355763419), 3e-07: np.float64(0.17898909548499695)}
# mass transfer coefficient: 1.8079866898799336e-06
# lambda_s_min: 0.9170819336245725
# Initial Sieving coefficient: 0.007513095375519711
# delta_m: 2.9562934033571115e-08
# phi_e_K_d: 1.3611978255202022e-05
# cake_membrane_porosity: 0.3515059470383278
# Peclet_m: 22.5136687951547
# Actual Sieving coefficient: 0.007513095376764173
# Sieving coefficient: 0.4005623580613637
# Yields: 0.7985571241332678
# J_flux increased to 8.505611840854818e-06
# Iteration 0: Packing constraints are met.
# {1e-08: np.float64(0.25758792345619297), 1.8e-07: np.float64(0.4589350001483944), 3e-07: np.float64(0.18423759855175417)}
# mass transfer coefficient: 1.812579301802697e-06
# lambda_s_min: 0.9832563123088104
# Initial Sieving coefficient: 0.0002809507538399833
# delta_m: 2.8525095027798668e-08
# phi_e_K_d: 1.0170212249146638e-08
# cake_membrane_porosity: 0.27811619141957356
# Peclet_m: 1384.6503956411125
# Actual Sieving coefficient: 0.0002809507538399833
# Sieving coefficient: 0.024751282788945127
# Yields: 0.09426193947145989
# J_flux increased to 8.570593987427975e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.277360243778291), 1.8e-07: np.float64(0.42166469566928627), 3e-07: np.float64(0.1765067839884248)}
# mass transfer coefficient: 1.813924110658325e-06
# lambda_s_min: 0.954756459359899
# Initial Sieving coefficient: 0.002132056505859733
# delta_m: 2.895443197961244e-08
# phi_e_K_d: 8.912604386658412e-07
# cake_membrane_porosity: 0.30975470944166006
# Peclet_m: 109.5208047813515
# Actual Sieving coefficient: 0.002132056505859733
# Sieving coefficient: 0.1626536995611461
# Yields: 0.4782750774257276
# J_flux increased to 8.589684513540284e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.2609840080455923), 1.8e-07: np.float64(0.4506558764306322), 3e-07: np.float64(0.17685015106395383)}
# mass transfer coefficient: 1.8150119480336095e-06
# lambda_s_min: 0.9641226413103994
# Initial Sieving coefficient: 0.0013240788887809991
# delta_m: 2.881053466112882e-08
# phi_e_K_d: 3.13828283555524e-07
# cake_membrane_porosity: 0.2993604532975387
# Peclet_m: 199.2348045486054
# Actual Sieving coefficient: 0.0013240788887809991
# Sieving coefficient: 0.10809176407445019
# Yields: 0.3510288759764113
# J_flux increased to 8.605147869639727e-06
# Iteration 1: Packing constraints are met.
# {1e-08: np.float64(0.27768698360771227), 1.8e-07: np.float64(0.4227263950331638), 3e-07: np.float64(0.17673323800548874)}
# Warning: No solution found within the iteration limit.
# (    name        radius  max_velocity    source
# 0   10nm  1.000000e-08      0.000008  brownian
# 1  180nm  1.800000e-07      0.000008     shear
# 2  300nm  3.000000e-07      0.000008     shear, {1e-08: np.float64(0.27768698360771227), 1.8e-07: np.float64(0.4227263950331638), 3e-07: np.float64(0.17673323800548874)}, 0.3510288759764113)
